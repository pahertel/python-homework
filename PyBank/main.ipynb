# %%
# PyBank

# Variables
total_months = 0
total_pnl = 0
total_change = 0
avg_change = 0
maximum_pnl = 0
minimum_pnl = 0
maximum_date = []
minimum_date = []

count_total_pnl = 0
date = []    
profit_loss = []
count_avg = []

# Import list
from pathlib import Path
import csv


csvpath = Path('../PyBank/budget_data.csv')


line_num = 0
with open(csvpath,'r') as csvfile:
    
    csvreader = csv.reader(csvfile, delimiter=',')
        
    header = next(csvreader)
    line_num += 1
    
    
    for row in csvreader:
        #print(row)
        pnls = int(row[1])
        profit_loss.append(pnls)
        
        dates = str(row[0])
        date.append(dates)
        
        total_months += 1
        

        
# Min and Max Values        
for pnls in profit_loss:
    
    total_pnl += pnls
    count_total_pnl += 1
    
    if minimum_pnl == 0:
        minimum_pnl = pnls
    elif pnls > maximum_pnl:
        maximum_pnl = pnls
    elif pnls < minimum_pnl:
        minimum_pnl = pnls

line_num2 = 0        
with open(csvpath,'r') as csvfile:
    
    csvreader = csv.reader(csvfile, delimiter=',')
        
    header = next(csvreader)
    line_num2 += 1
    
    for row in csvreader:
# Dates for corresposing min and max        
        if int(row[1]) == maximum_pnl:
            maximum_date.append(row[0])

        if int(row[1]) == minimum_pnl:
            minimum_date.append(row[0])


#Average Change            
    for avg in count_avg:
    
        total_change += sum(avg['Profit/Losses'][i+1] - avg['Profit/Losses'][i-1])
        count_total_change += 1            
            
    
avg_change = total_change/(total_months-1)

print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {total_months}")
print(f"Total: ${total_pnl}")
print(f"Average Change: {avg_change}")
print(f"Greatest Increase in Profits: {maximum_date} (${maximum_pnl})")
print(f"Greatest Decrease in Profits: {minimum_date} (${minimum_pnl})")
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total: $38382578
# Average Change: 0.0
# Greatest Increase in Profits: ['Feb-12'] ($1170593)
# Greatest Decrease in Profits: ['Sep-13'] ($-1196225)
